# %%
ADAPTATION_POLICY_DESCRIPTION = """Adaptation policies: Policies designed to increase resilience to climate impacts such as extreme weather events, rising sea levels, or changing resource availability. Examples include flood defense infrastructure, heatwave preparedness 
plans, drought-resilient agricultural practices, and urban greening for cooling. 
Policies were classified as adaptation when their main goal was to manage climate 
risks and vulnerabilities."""

# %%
import dspy

# %%
from attachments.dspy import Attachments

# %%
from openai import OpenAI

# %%
lm = dspy.LM('openai/gpt-5-nano')
dspy.configure(lm=lm)

# %%
categories = [
    "Social and Equity",
    "Environmental and Resources",
    "Governance and Policy",
    "Housing and Infrastructure"
]#unique ones
class PolicyCategory(dspy.Signature):
    """Defines the unique policy categories."""
    category: str = dspy.InputField(choices=categories)  # Restrict input to these categories

# %%
#attempt 2
class ExtractAdaptationPolicies(dspy.Signature):
    """
    Task: Extract ALL  policies related to the policy_type defined by the policy_definition from the document.
    
    For each policy found, provide:
      1. A specific, descriptive policy name (not generic headings)
      2. Verbatim snippets (2-4 quotes) from the document that describe the policy
    
    Return two parallel lists of the same length:
      - policy_names: concise but encompassing names for each policy
      - policy_details: for each policy, provide verbatim snippets (word-for-word quotes)
                       from the document. You may use multiple non-contiguous snippets.
      - MAKE SURE THE LISTS ARE ALIGNED BY INDEX AND OF THE SAME LENGTH 
    
    Rules:
      - Policy names should be specific and action-oriented, leave details to the details section and let title be a title
      - Details must be quoted verbatim from the source (no paraphrasing)
      - Lists must be the SAME length and aligned by index
      - Extract ALL policies, even if there are many
    """
    
    # Inputs
    document: Attachments = dspy.InputField()
    country: str = dspy.InputField()
    state_or_province: str | None = dspy.InputField()
    city: str | None = dspy.InputField()
    policy_type: str = dspy.InputField()
    policy_definition: str = dspy.InputField()
    
    # Outputs
    policy_names: list[str] = dspy.OutputField(
        desc="List of specific, descriptive policy names"
    )
    #got it to print out the same result
    policy_details: list[list[str]] = dspy.OutputField(
        desc="List of verbatim snippets for each policy (same length as policy_names for outer list)"
    )

# %%
from dataclasses import dataclass, field
from typing import List
@dataclass
class PDFPolicies:
    """All adaptation policies extracted from a single PDF."""
    pdf_path: str
    country: str
    state_or_province: str | None
    city: str | None
    policy_names: List[str] = field(default_factory=list)
    policy_details: List[List[str]] = field(default_factory=list)  # list of snippets per policy

    def flatten_in_place(self, sep: str = " "):
        """
        Replace policy_details (list[list[str]]) with a single-string list representation.
        After this, policy_details becomes List[List[str]] where each inner list has one joined string.
        """
        self.policy_details = [sep.join(snips) for snips in self.policy_details]
    def add_from_dspy(self, result):
        """Populate from a DSPy result (ExtractAdaptationPolicies signature)."""
        self.policy_names = result.policy_names
        self.policy_details = result.policy_details
        self.flatten_in_place()

# %%
key_to_pdf = {
"Seattle":"pdfs/Seattle.pdf",
"Las Vegas":"pdfs/CLV.pdf",
"Miami-Dade":"pdfs/MIAMI_DADE.pdf",
"Hiroshima":"pdfs/HIROSHIMA.pdf",
"Geneva":"pdfs/city_of_geneva.pdf"
}

keys_to_details ={
    "Seattle":['United States','Washington'],
    "Las Vegas":['United States','Nevada'],
    "Miami-Dade":["United States","Florida"],
    "Hiroshima":["Japan","N/A"],
    "Geneva":["Switzerland","N/A"]
}

# %%
def build_policy_details(key_to_pdf,keys_to_details):
    city_to_details={}
    for city in key_to_pdf.keys():
        pdf_path = key_to_pdf[city]
        curr_city_policies = PDFPolicies(
        pdf_path=pdf_path,
        country=keys_to_details[city][0],
        state_or_province=keys_to_details[city][1],
        city=city,
        )
        curr_city_results = dspy.ChainOfThought(ExtractAdaptationPolicies)(
        document=Attachments(key_to_pdf[city]),
        country= keys_to_details[city][0],
        state_or_province=keys_to_details[city][1],
        city=city,
        policy_type="adaptation",  # fixed spelling
        policy_definition=ADAPTATION_POLICY_DESCRIPTION, # fixed name
        policy_categories=categories
)
        curr_city_policies.add_from_dspy(curr_city_results)
        city_to_details[city] = curr_city_policies
    return city_to_details

# %%
built_policies = build_policy_details(key_to_pdf,keys_to_details)
# Out:
# [Attachments] Running primary processor 'pdf_to_llm' for pdfs/Seattle.pdf
# [Attachments]   Applying step 'load.url_to_response' to pdfs/Seattle.pdf
# [Attachments]   Applying step 'modify.morph_to_detected_type' to pdfs/Seattle.pdf
# [Attachments]   Applying step 'load.pdf_to_pdfplumber' to pdfs/Seattle.pdf
# [Attachments]   Applying step 'modify.pages' to pdfs/Seattle.pdf
# [Attachments]   Running AdditivePipeline(present.markdown + present.images + present.metadata)
# [Attachments]     Applying additive step 'present.markdown' to pdfs/Seattle.pdf
# [Attachments]     Applying additive step 'present.images' to pdfs/Seattle.pdf
# [Attachments]     Applying additive step 'present.metadata' to pdfs/Seattle.pdf
# [Attachments]   Applying step 'refine.tile_images' to pdfs/Seattle.pdf
# [Attachments]   Applying step 'refine.resize_images' to pdfs/Seattle.pdf
# [Attachments] Running primary processor 'pdf_to_llm' for pdfs/CLV.pdf
# [Attachments]   Applying step 'load.url_to_response' to pdfs/CLV.pdf
# [Attachments]   Applying step 'modify.morph_to_detected_type' to pdfs/CLV.pdf
# [Attachments]   Applying step 'load.pdf_to_pdfplumber' to pdfs/CLV.pdf
# [Attachments]   Applying step 'modify.pages' to pdfs/CLV.pdf
# [Attachments]   Running AdditivePipeline(present.markdown + present.images + present.metadata)
# [Attachments]     Applying additive step 'present.markdown' to pdfs/CLV.pdf
# Cannot set gray non-stroke color because /'P0' is an invalid float value
# Cannot set gray stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray stroke color because /'P3' is an invalid float value
# Cannot set gray non-stroke color because /'P4' is an invalid float value
# Cannot set gray stroke color because /'P5' is an invalid float value
# Cannot set gray non-stroke color because /'P6' is an invalid float value
# Cannot set gray stroke color because /'P7' is an invalid float value
# Cannot set gray non-stroke color because /'P8' is an invalid float value
# Cannot set gray stroke color because /'P9' is an invalid float value
# Cannot set gray non-stroke color because /'P10' is an invalid float value
# Cannot set gray stroke color because /'P11' is an invalid float value
# Cannot set gray non-stroke color because /'P12' is an invalid float value
# Cannot set gray stroke color because /'P13' is an invalid float value
# Cannot set gray non-stroke color because /'P14' is an invalid float value
# Cannot set gray stroke color because /'P15' is an invalid float value
# Cannot set gray non-stroke color because /'P16' is an invalid float value
# Cannot set gray stroke color because /'P17' is an invalid float value
# Cannot set gray non-stroke color because /'P18' is an invalid float value
# Cannot set gray stroke color because /'P19' is an invalid float value
# Cannot set gray non-stroke color because /'P20' is an invalid float value
# Cannot set gray stroke color because /'P21' is an invalid float value
# Cannot set gray non-stroke color because /'P22' is an invalid float value
# Cannot set gray stroke color because /'P23' is an invalid float value
# Cannot set gray non-stroke color because /'P24' is an invalid float value
# Cannot set gray stroke color because /'P25' is an invalid float value
# Cannot set gray non-stroke color because /'P26' is an invalid float value
# Cannot set gray stroke color because /'P27' is an invalid float value
# Cannot set gray non-stroke color because /'P28' is an invalid float value
# Cannot set gray stroke color because /'P29' is an invalid float value
# Cannot set gray non-stroke color because /'P30' is an invalid float value
# Cannot set gray stroke color because /'P31' is an invalid float value
# [Attachments]     Applying additive step 'present.images' to pdfs/CLV.pdf
# [Attachments]     Applying additive step 'present.metadata' to pdfs/CLV.pdf
# [Attachments]   Applying step 'refine.tile_images' to pdfs/CLV.pdf
# [Attachments]   Applying step 'refine.resize_images' to pdfs/CLV.pdf
# [Attachments] Running primary processor 'pdf_to_llm' for pdfs/MIAMI_DADE.pdf
# [Attachments]   Applying step 'load.url_to_response' to pdfs/MIAMI_DADE.pdf
# [Attachments]   Applying step 'modify.morph_to_detected_type' to pdfs/MIAMI_DADE.pdf
# [Attachments]   Applying step 'load.pdf_to_pdfplumber' to pdfs/MIAMI_DADE.pdf
# [Attachments]   Applying step 'modify.pages' to pdfs/MIAMI_DADE.pdf
# [Attachments]   Running AdditivePipeline(present.markdown + present.images + present.metadata)
# [Attachments]     Applying additive step 'present.markdown' to pdfs/MIAMI_DADE.pdf
# Cannot set gray stroke color because /'P0' is an invalid float value
# Cannot set gray stroke color because /'P1' is an invalid float value
# Cannot set gray stroke color because /'P0' is an invalid float value
# Cannot set gray stroke color because /'P0' is an invalid float value
# Cannot set gray stroke color because /'P0' is an invalid float value
# [Attachments]     Applying additive step 'present.images' to pdfs/MIAMI_DADE.pdf
# [Attachments]     Applying additive step 'present.metadata' to pdfs/MIAMI_DADE.pdf
# [Attachments]   Applying step 'refine.tile_images' to pdfs/MIAMI_DADE.pdf
# [Attachments]   Applying step 'refine.resize_images' to pdfs/MIAMI_DADE.pdf
# [Attachments] Running primary processor 'pdf_to_llm' for pdfs/HIROSHIMA.pdf
# [Attachments]   Applying step 'load.url_to_response' to pdfs/HIROSHIMA.pdf
# [Attachments]   Applying step 'modify.morph_to_detected_type' to pdfs/HIROSHIMA.pdf
# [Attachments]   Applying step 'load.pdf_to_pdfplumber' to pdfs/HIROSHIMA.pdf
# [Attachments]   Applying step 'modify.pages' to pdfs/HIROSHIMA.pdf
# [Attachments]   Running AdditivePipeline(present.markdown + present.images + present.metadata)
# [Attachments]     Applying additive step 'present.markdown' to pdfs/HIROSHIMA.pdf
# [Attachments]     Applying additive step 'present.images' to pdfs/HIROSHIMA.pdf
# [Attachments]     Applying additive step 'present.metadata' to pdfs/HIROSHIMA.pdf
# [Attachments]   Applying step 'refine.tile_images' to pdfs/HIROSHIMA.pdf
# [Attachments]   Applying step 'refine.resize_images' to pdfs/HIROSHIMA.pdf
# [Attachments] Running primary processor 'pdf_to_llm' for pdfs/city_of_geneva.pdf
# [Attachments]   Applying step 'load.url_to_response' to pdfs/city_of_geneva.pdf
# [Attachments]   Applying step 'modify.morph_to_detected_type' to pdfs/city_of_geneva.pdf
# [Attachments]   Applying step 'load.pdf_to_pdfplumber' to pdfs/city_of_geneva.pdf
# [Attachments]   Applying step 'modify.pages' to pdfs/city_of_geneva.pdf
# [Attachments]   Running AdditivePipeline(present.markdown + present.images + present.metadata)
# [Attachments]     Applying additive step 'present.markdown' to pdfs/city_of_geneva.pdf
# [Attachments]     Applying additive step 'present.images' to pdfs/city_of_geneva.pdf
# [Attachments]     Applying additive step 'present.metadata' to pdfs/city_of_geneva.pdf
# [Attachments]   Applying step 'refine.tile_images' to pdfs/city_of_geneva.pdf
# [Attachments]   Applying step 'refine.resize_images' to pdfs/city_of_geneva.pdf

# %%
class ClassifyPolicy(dspy.Signature):
    """
    Task: Classify a single policy into ONE primary category.
    
    Categories and their definitions:
    
    1. Housing and Infrastructure
       - Physical buildings, construction standards, urban development
       - Transportation networks (roads, transit, cycling infrastructure)
       - Utilities and service infrastructure (water, electricity)
       - Building codes, retrofitting, climate-resilient design
    
    2. Environmental and Resources
       - Natural ecosystems, biodiversity, habitat conservation
       - Water resource management, watershed management
       - Energy resources (renewable energy, energy mix)
       - Air quality, pollution control, environmental monitoring
       - Land use, soil management, forestry
    
    3. Economic and Employment
       - Job creation, workforce development, skills training
       - Business support, economic incentives, financial programs
       - Industry transformation, economic diversification
       - Carbon pricing, green finance, investment frameworks
       - Livelihood support, economic resilience
    
    4. Social and Equity
       - Vulnerable populations, community welfare, social justice
       - Public health, healthcare access, disease prevention
       - Housing affordability, social housing programs
       - Education, awareness campaigns, community engagement
       - Food security, access to services
       - Cultural preservation, indigenous rights
    
    5. Governance and Policy
       - Legislation, regulations, legal frameworks
       - Planning processes, strategic frameworks, policy integration
       - Institutional coordination, inter-agency collaboration
       - Monitoring and evaluation systems, reporting requirements
       - Emergency management, disaster preparedness systems
       - Data management, information systems
    
    Classification Priority:
    1. The explicit stated goal of the policy
    2. The primary action or intervention described
    3. The main beneficiary or target of the policy
    """
    
    policy_name: str = dspy.InputField()
    policy_details: str = dspy.InputField()
    country: str = dspy.InputField()
    state_or_province: str | None = dspy.InputField()
    city: str | None = dspy.InputField()
    
    primary_category: str = dspy.OutputField(
        desc="ONE of: Housing and Infrastructure, Environmental and Resources, "
             "Economic and Employment, Social and Equity, Governance and Policy"
    )
    confidence: str = dspy.OutputField(
        desc="high, medium, or low"
    )
    reasoning: str = dspy.OutputField(
        desc="2-3 sentences explaining why this is the PRIMARY category"
    )

# %%
def classify_policies(built_polcies):
    #gonna be a city: [{policy_name : result}]
    policy_classifier_dict = {}
    for city in built_polcies.keys():
        city_policy_classifier_list = []
        for i in range(len(built_policies[city].policy_names)):
            policy_name = built_policies[city].policy_names[i]
            policy_details = built_polcies[city].policy_details[i]
            classification_result = dspy.ChainOfThought(ClassifyPolicy)(
                policy_name=policy_name,
                policy_details=policy_details,
                country=built_policies[city].country,
                state_or_province=built_policies[city].state_or_province,
                city=built_policies[city].city,
            )
            city_policy_classifier_list.append({policy_name: classification_result})
        policy_classifier_dict[city] = city_policy_classifier_list
    return policy_classifier_dict

# %%
classified_policies = classify_policies(built_policies)

# %%
# want to see where the list indices don't match up, if they do, go back and iterate on prompt
#interesting part to do batching for later, since you do need them to match and if you have a big problem then they won't
for city in built_policies.keys():
    num_names = len(built_policies[city].policy_names)
    num_details = len(built_policies[city].policy_details)
    if num_names != num_details:
        print(f"Mismatch in {city}: {num_names} names vs {num_details} details")
        for i in range(max(num_names, num_details)):
            name = built_policies[city].policy_names[i] if i < num_names else None
            detail = built_policies[city].policy_details[i] if i < num_details else None
            print(f"Index {i}: Name = {name}, Detail = {detail}")

# %%
classified_policies
# Out:
# {'Seattle': [{'Countywide Tree Canopy Expansion and Facility Canopy Standards': Prediction(
#        reasoning='It focuses on expanding tree canopy and setting canopy targets for urban and county facilities, which is a land-use/forestry action tied to environmental stewardship. The primary intervention is urban forestry and canopy management (forestry resources within urban areas).',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Biscayne Bay Seagrass Recovery and Pollution Load Reductions': Prediction(
#        reasoning='The policy aims to improve water quality by reducing pollutant loads into surface waters and to restore seagrass habitat, focusing on pollution control and ecosystem restoration. Its primary actions involve pollutant load reduction targets and water resource management, rather than infrastructure, economics, governance structures, or social equity. Therefore, the Environmental and Resources category is the best fit.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Double Non‑Wetland Natural Habitat in Preservation': Prediction(
#        reasoning='This policy centers on expanding and monitoring natural habitat preservation and assessing ecological quality, including carbon sequestration. It also involves environmental land protection and transfer to a conservation program. These aspects are clearly about environmental resources and habitat conservation.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Wetland Acquisition, No Net Loss, and Restoration Partnerships': Prediction(
#        reasoning='The policy centers on conserving and restoring wetland ecosystems, including acquisition and protection of wetlands, and support for Everglades restoration. The primary actions focus on habitat conservation, water resources management, and preventing net loss of wetlands. While it involves regulatory enforcement, the main intent is environmental resources preservation and restoration.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Living Shorelines Enhancement in Biscayne Bay': Prediction(
#        reasoning='The policy focuses on enhancing living shorelines and restoring coastal wetlands to protect water quality and coastal ecosystems, indicating an environmental and natural resource management aim. The primary action involves habitat restoration and shoreline protection, rather than housing, governance, or economic incentives. The main beneficiaries are the environment and the public who benefit from healthier coastal ecosystems.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Florida‑Friendly Landscaping and Canal‑Adjacent Landscape Re‑certification': Prediction(
#        reasoning='The policy centers on promoting water-saving landscaping practices and reducing fertilizer runoff, which are core environmental resource management goals. The main intervention is adopting Florida Friendly Landscaping standards as the default and requiring canal-adjacent landscape re-certification, aligning with environmental protection and water resources management.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Shade and Heat‑Safe Transit and Play Spaces': Prediction(
#        reasoning='This policy centers on shaping public spaces—bus stops and parks—by adding shade. Its primary actions are urban design and infrastructure modifications to improve comfort, safety, and resilience in transit and recreation areas, which aligns with Housing and Infrastructure more than environmental management or social services.',
#        primary_category='Housing and Infrastructure',
#        confidence='high'
#    )},
#   {'Ecosystem Tracking and Green Infrastructure Net Gain Policy': Prediction(
#        reasoning='The policy centers on measuring and managing ecosystems, habitat protection, and carbon sequestration through a net gain in green infrastructure, which is a clear environmental/resource management focus. The primary actions involve assessment, tracking, reporting, and mitigation to achieve ecological benefits, rather than housing, social equity, or governance alone.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'One Water Approach and Per‑Capita Water Use Reduction': Prediction(
#        reasoning='The policy centers on reducing per-capita water use and adopting a One Water approach to manage water resources and infrastructure. It emphasizes water resource management, conservation, and ecosystem protection to secure long-term supply. These are core environmental/resource concerns rather than housing, economic, or governance aims.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Landscape Irrigation Rebate Program and Water Conservation Rebates': Prediction(
#        reasoning='The policy centers on reducing water usage and improving efficiency through rebates and assessments, which is a core water resource management and environmental protection activity. Its primary actions are conservation incentives (rebates for high-efficiency fixtures and site assessments), not construction or housing infrastructure. The main beneficiaries are residents and businesses, aligning with environmental and resources objectives.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Expand Local Forests and Protect Specimen Trees': Prediction(
#        reasoning='The policy focuses on expanding local forests and protecting specimen trees, which directly relates to natural ecosystems, biodiversity conservation, and habitat management. The primary actions are forest expansion planning and updating regulations to safeguard trees, aligning with Environmental and Resources rather than housing, governance, or social programs.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )}],
#  'Las Vegas': [{'Countywide Tree Canopy Expansion Mandate': Prediction(
#        reasoning='The policy focuses on expanding and regulating tree canopy and urban forestry, which directly relates to natural resources, ecological health, and green infrastructure. Its primary purpose is environmental resource management rather than building infrastructure or purely governance processes, despite the regulatory framing. Therefore Environmental and Resources is the most appropriate primary category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Heat-Equity Tree Planting and Shade Initiatives': Prediction(
#        reasoning='The policy centers on planting shade trees to mitigate heat exposure and reduce utility burdens, which is a direct environmental resource management action (urban forestry) aimed at cooling and resilience. While it also supports social equity and public health goals, the primary intervention is environmental infrastructure—trees and shade.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Heat-Safe Transit Stops (Shaded Bus Shelters)': Prediction(
#        reasoning='The policy centers on modifying transit infrastructure—shade-providing locations and solar-powered bus shelters—rather than broader environmental management or social programs. By design, it directly affects transportation infrastructure and related utilities, improving the built environment for transit users.',
#        primary_category='Housing and Infrastructure',
#        confidence='high'
#    )},
#   {'Biscayne Bay Seagrass Recovery and Pollutant Load Reduction': Prediction(
#        reasoning='This policy centers on reducing pollutant loads to surface waters to restore seagrass habitat, a core environmental resource protection objective. The primary actions are water quality improvements, development of BMPs, and setting pollutant-load targets aimed at ecosystem restoration, rather than economic development or governance functions. The main beneficiary is the aquatic ecosystem and seagrass habitat in Biscayne Bay.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Living Shorelines Enhancement in Biscayne Bay': Prediction(
#        reasoning='The policy focuses on restoring and enhancing coastal ecosystems (living shorelines and wetlands) and protecting water resources, which are core environmental and natural resource management concerns. The primary actions described are ecosystem restoration and habitat protection, aligning with Environmental and Resources rather than social or governance aspects.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Wetland Acquisition and Everglades Restoration Partnership': Prediction(
#        reasoning='The policy centers on acquiring wetlands and supporting restoration projects for the Everglades, emphasizing preservation of natural ecosystems and water resources. The core actions involve habitat protection, wetland preservation, and restoration partnerships, aligning with environmental and resources management rather than housing, economy, or governance. Therefore, the primary category is Environmental and Resources.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'No Net Loss of Wetland Area and Function Enforcement': Prediction(
#        reasoning='The policy centers on protecting wetlands and their ecosystem function through strengthened enforcement of environmental regulations, which is a core environmental resources objective. While enforcement is involved, the primary focus is on preserving natural ecosystems and habitat integrity.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Green Infrastructure Net-Gain Requirement for Development': Prediction(
#        reasoning='The policy centers on expanding and tracking green infrastructure, habitat protection, and carbon sequestration, which are core environmental resource management activities. Its primary actions involve measuring ecosystem acreage and quality and reporting on ecological outcomes, aligning with environmental stewardship rather than housing, governance, or social equity. Therefore, the primary focus is Environmental and Resources.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Countywide Resilient Landscaping Standards': Prediction(
#        reasoning='The policy focuses on water-efficient landscaping standards and the reuse of vegetation as mulch, both of which are environmental resource management actions aimed at conserving water and reducing nutrient runoff. Its primary focus is environmental stewardship and land use practices, rather than housing construction, social programs, or economic incentives.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Landscape Re-certification Near Canals to Protect Bay Water Quality': Prediction(
#        reasoning='This policy focuses on protecting water quality and aquatic ecosystems by regulating landscaping practices near canal features that drain into a surface water body (Biscayne Bay). The main action is reducing pollutant loads to surface waters to support seagrass recovery, aligning with environmental and water resource management rather than infrastructure, governance, or economic development.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Forest Expansion and Specimen Tree Protection': Prediction(
#        reasoning='Core aims are expanding local forests, protecting specimen trees, and transferring land to a conservation program, all of which center on natural ecosystems and resource management. These actions align with environmental protection, biodiversity, and land/conservation planning rather than housing, infrastructure, or economic policy.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Countywide Water Conservation and Irrigation Efficiency': Prediction(
#        reasoning='This policy focuses on managing a natural resource (water) through conservation targets and rebates for water-efficient technologies, emphasizing environmental sustainability and water resource management. The primary interventions are reducing per-capita water use and promoting efficient irrigation and fixtures, rather than expanding infrastructure or providing direct social services.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )}],
#  'Miami-Dade': [{'Countywide Tree Canopy Expansion and Facility Canopy Requirements': Prediction(
#        reasoning="The policy's explicit goal is to expand urban tree canopy coverage by 2030 and apply canopy targets to county facilities, which directly addresses natural resources, ecosystem services, and environmental quality. The primary action is environmental resource management through urban forestry and canopy expansion, making Environmental and Resources the most appropriate category.",
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Biscayne Bay Seagrass Recovery through Pollutant Load Reductions and SAV Restoration': Prediction(
#        reasoning='The policy aims to recover an aquatic ecosystem (Biscayne Bay seagrass) by reducing pollutant loads and restoring submerged aquatic vegetation, clearly targeting environmental health and habitat restoration. While it mentions governance actions like BMPs and codified load limits, the primary objective and intervention are environmental in nature, focusing on ecosystem restoration and water quality.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Wetland and Natural Habitat Preservation: Acquisition, No Net Loss, and Restoration': Prediction(
#        reasoning='The policy centers on protecting wetlands and natural habitats through acquisition, restoration, and enforcement of environmental regulations, aiming for no net loss of ecological function. Its primary actions are habitat protection/restoration and resource management within the Miami-Dade/Everglades context, rather than housing, governance, or purely economic incentives.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Coastal Resilience: Enhance Living Shorelines and Restore Filled Coastal Wetlands': Prediction(
#        reasoning='The policy focuses on coastal habitat protection and restoration through living shorelines and wetland restoration, targeting coastal ecosystems and water resources. Although it references regulatory compliance, the core interventions are ecological restoration and habitat conservation, which align with Environmental and Resources rather than infrastructure or governance alone.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Heat-Safe Transit Stops with Shaded Bus Infrastructure': Prediction(
#        reasoning='This policy centers on the physical design of transit infrastructure—specifically shade for bus stops—to mitigate extreme heat. The primary action is infrastructure and urban development related to transportation networks, aligning with Housing and Infrastructure rather than purely environmental or health objectives.',
#        primary_category='Housing and Infrastructure',
#        confidence='high'
#    )},
#   {'Growing Green Playgrounds: Shade Trees to Cool Playgrounds': Prediction(
#        reasoning='The policy focuses on planting shade trees to reduce surface temperatures in playgrounds, which is an environmental resource management action (urban forestry) aimed at climate adaptation and public health. The primary intervention is expanding natural cover to improve environmental conditions, rather than initiating housing, economic, or governance changes.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Florida Friendly Landscaping and Landscape Re‑Certification to Reduce Runoff': Prediction(
#        reasoning='The policy centers on reducing nutrient runoff and conserving water by mandating Florida Friendly Landscaping standards and re-certification near canal features that drain into Biscayne Bay. These actions target watershed health, water resource management, and pollution prevention rather than construction or infrastructure development. Therefore, Environmental and Resources is the primary category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Landscape Irrigation Rebate Program and Water Conservation for Sea Level Rise Preparedness': Prediction(
#        reasoning='The policy focuses on water resource management and conservation, with rebates for water-efficient landscaping and irrigation to protect ecosystems and ensure a reliable water supply. It explicitly targets reducing outdoor water use, an environmental resource management action. Therefore Environmental and Resources is the primary category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Prioritized Tree Planting in Heat- and Utility-Burdened Neighborhoods': Prediction(
#        reasoning='The policy focuses on expanding urban tree canopy to mitigate heat and reduce utility burden, which directly relates to natural ecosystems, resource management, and environmental quality. The primary intervention is an environmental intervention (tree planting) with climate and energy-use benefits, rather than construction, governance processes, or social services. Therefore, Environmental and Resources is the most appropriate primary category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Parks and Open Space for Flood Mitigation (Open Space Master Plan)': Prediction(
#        reasoning='The policy centers on using parks and open spaces to absorb floodwaters, which is a water resource management and flood mitigation measure. By repurposing green spaces for stormwater detention, the Open Space Master Plan prioritizes environmental infrastructure and land-use strategies to reduce flood risk.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )}],
#  'Hiroshima': [{'Countywide Tree Canopy Expansion to 30% by 2030': Prediction(
#        reasoning='The policy centers on expanding tree canopy and urban forestry, which directly relates to environmental resource management, ecosystems, and land use. Its primary action is increasing green infrastructure and preserving natural resources within the county, focusing on environmental benefits rather than governance or housing specifics.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Facility Canopy Coverage Targets (30% inside UDB; 50% outside) by 2030': Prediction(
#        reasoning='The policy centers on increasing and protecting tree canopy coverage, which is a core environmental resource management issue (shade, stormwater management, carbon storage, and health benefits). Its primary actions are protecting existing trees and planting new ones, i.e., urban forestry and ecosystem services. This focus is squarely on environmental resources rather than housing, governance, or social programs.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Prioritized Tree Planting in Hottest and Highest Utility-Burden Neighborhoods': Prediction(
#        reasoning='This policy centers on selecting neighborhoods for tree planting to reduce heat and alleviate utility burden, prioritizing urban forestry and canopy expansion. The primary intervention is expanding vegetation and green infrastructure in urban areas to improve environmental outcomes and resilience.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Biscayne Bay Pollutant Load Reductions to Restore Seagrasses': Prediction(
#        reasoning='The policy aims to reduce pollutant loads to surface waters to restore seagrasses, focusing on water quality and pollutant load management. This centers on environmental resources and ecosystem restoration rather than housing, economic, or governance actions.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Restore and Protect Submerged Aquatic Vegetation (SAV) in Biscayne Bay': Prediction(
#        reasoning='This policy centers on conserving and restoring a natural aquatic habitat (submerged aquatic vegetation) and mitigating sediment-related impacts from dredging, which are core Environmental and Resources concerns. The primary action is habitat restoration and protection, targeting the aquatic ecosystem rather than infrastructure, housing, or social programs.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Enhance Living Shorelines in Biscayne Bay': Prediction(
#        reasoning='The policy focuses on restoring and enhancing living shorelines and protecting marine/coastal habitats, highlighting natural ecosystem conservation and carbon sequestration benefits. The primary action is ecosystem-based coastal management and habitat restoration, rather than housing infrastructure, economic incentives, or governance processes. This aligns with Environmental and Resources through its emphasis on ecosystems, water bodies, and habitat preservation.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Double Non‑Wetland Natural Habitat in Preservation': Prediction(
#        reasoning='The policy centers on preserving and expanding natural habitats to boost carbon sequestration and climate resilience, which is a core environmental resource issue. Its explicit objective is habitat preservation and environmental protection, making Environmental and Resources the primary category over housing, governance, or social program domains.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Wetland Acquisition for Everglades Restoration and EEL Program': Prediction(
#        reasoning='The policy centers on acquiring and preserving wetlands and supporting restoration of wetland ecosystems as part of the Everglades restoration effort, which involves natural resource management, ecosystem preservation, and water resource considerations. The primary focus is on environmental resources and habitat restoration rather than housing, economics, social equity, or governance structures alone.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Eliminate Net Loss of Wetland Area and Function': Prediction(
#        reasoning='The policy focuses on preventing the net loss of wetlands and maintaining wetland area and ecosystem function, which is a core environmental and resource management objective. Although it mentions enforcement of regulations, the central aim is protecting natural resources and ecological services provided by wetlands.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Restore Historically Filled County‑Owned Coastal Wetlands': Prediction(
#        reasoning='The policy focuses on restoring coastal wetland habitats and preserving ecological connectivity, targeting natural ecosystems, water resources, and biodiversity. The main action is ecological restoration of habitat rather than construction, governance, or social programs. Therefore Environmental and Resources is the most fitting category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Florida‑Friendly Landscaping as Default on County Lands': Prediction(
#        reasoning='The policy aims to protect environmental resources by promoting water-saving landscaping and reducing fertilizer runoff, which are core environmental/resource management concerns. The primary action is to standardize landscaping practices (Florida Friendly Landscaping) on county lands, with specific implications for water bodies like canals feeding Biscayne Bay. Therefore, Environmental and Resources is the primary category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Development Mitigation Policy for Net Increase in Green Infrastructure': Prediction(
#        reasoning='The policy focuses on net increases in green infrastructure, habitat protection, and monitoring ecosystem acreage and quality to assess carbon sequestration. These elements are central to environmental resources management and biodiversity protection. Therefore Environmental and Resources is the primary category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Ecosystem Acreage and Quality Monitoring and Reporting': Prediction(
#        reasoning='The policy centers on measuring and reporting changes in ecosystem acreage and quality, and assessing associated ecosystem services like carbon sequestration and shade. These activities focus on natural resources management and environmental monitoring rather than housing, governance, or social policy, placing it squarely in Environmental and Resources.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Landscape Re‑Certification Near Canals Flowing to Biscayne Bay': Prediction(
#        reasoning='This policy centers on protecting a waterway and reducing nutrient runoff by regulating landscaping near canals that feed Biscayne Bay and by mandating water-efficient practices (Florida Friendly Landscaping). The core aim is environmental/resource management, focusing on water conservation and pollution prevention, with certification procedures as a governance mechanism but not the primary driver.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Expand Local Forests Through Inter‑Agency Partnerships': Prediction(
#        reasoning='The primary objective is expanding local forests and preserving natural habitat, which directly concerns ecosystems, land use, and resource management. Inter-agency partnerships are a governance mechanism, but the intervention targets environmental resources and habitat conservation.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Per‑Capita Water Consumption Reduction (30% by 2030)': Prediction(
#        reasoning='The policy targets reducing per-capita water use and managing water resources, which directly relates to conserving water, protecting ecosystems, and ensuring a reliable supply. Its emphasis on a long-term water efficiency goal indicates a resource-management focus rather than housing, infrastructure, or social services.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Landscape Irrigation Rebate Program (LIRP) for Efficient Irrigation Systems': Prediction(
#        reasoning='The program is centered on conserving water resources by incentivizing water-efficient irrigation and landscape retrofits, addressing environmental resource management and sustainability. The primary action is providing rebates and assessments to implement efficient irrigation systems, which aligns with Environmental and Resources. The main beneficiaries are property owners of single-family homes and large commercial properties.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Water Conservation Rebates for High‑Efficiency Fixtures': Prediction(
#        reasoning='The policy centers on conserving water and managing water resources by providing rebates to encourage the installation of high-efficiency fixtures, thereby reducing demand and energy use in the water system. The core action is water-use efficiency and resource management, not housing construction, economic incentives, or governance processes, aligning it with Environmental and Resources.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Shade Bus Stops to Safeguard Transit Users from Extreme Heat': Prediction(
#        reasoning='Shade bus stops is a physical infrastructure intervention aimed at improving transit infrastructure and urban development to reduce heat exposure for users. While public health is a motivation, the primary action is modifying the built environment to support transportation networks, which aligns with Housing and Infrastructure.',
#        primary_category='Housing and Infrastructure',
#        confidence='high'
#    )},
#   {'Growing Green Playgrounds: Shade Tree Planting at Playgrounds': Prediction(
#        reasoning='The policy centers on planting shade trees to reduce high surface temperatures in playgrounds, a nature-based environmental intervention for heat mitigation and urban resilience. The primary action is environmental resource management (urban forestry) rather than housing, governance, or economic policy.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Use Removed Vegetative Material as Mulch and Provide Public Access': Prediction(
#        reasoning='The policy centers on repurposing removed vegetative material as mulch and making it available to the public, which is a core environmental resource management activity. It also involves protecting and transferring land to an Environmental Endangered Lands Program, aligning with habitat conservation and land stewardship. The governance elements exist but the primary action is environmental resource management.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Explore License Fee Funding for Green and Blue Restoration Projects': Prediction(
#        reasoning='The policy centers on financing restoration of natural resources (green and blue ecosystems). The main action is using fishing license fees to fund environmental restoration projects, which is a direct environmental/resource management intervention; governance aspects are secondary support.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )}],
#  'Geneva': [{'Countywide Urban Tree Canopy Expansion and Facility Canopy Standards': Prediction(
#        reasoning='The policy centers on expanding urban tree canopy and setting canopy targets, which is fundamentally about managing natural ecosystems, forestry, and land use within the urban environment. Its primary aim is environmental quality and resilience benefits (heat mitigation, air quality, habitat considerations), aligning with Environmental and Resources.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Shade and Heat Protection for Transit and Playgrounds': Prediction(
#        reasoning='The policy centers on modifying urban infrastructure (bus stops and playground shade) to reduce heat exposure and improve safety, which is a core Housing and Infrastructure concern. While it also yields health and environmental benefits, the primary action is creating or enhancing physical transit and recreational infrastructure.',
#        primary_category='Housing and Infrastructure',
#        confidence='medium'
#    )},
#   {'Biscayne Bay Seagrass Recovery and Water Quality Load Reductions': Prediction(
#        reasoning='The policy centers on reducing pollutant loads to surface waters to restore seagrass habitats, which directly concerns environmental resources and habitat restoration. The explicit actions describe water-quality improvements and seagrass recovery rather than housing, economy, or governance, making Environmental and Resources the primary focus.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Wetland Acquisition, Preservation, and No Net Loss Enforcement': Prediction(
#        reasoning='The policy centers on protecting wetlands, preserving natural ecosystems, and enforcing no-net-loss of wetland areas, which directly involves natural resources management and environmental protection. It emphasizes restoration and regulatory enforcement related to water resources and biodiversity, not housing, infrastructure, or social programs. Therefore, Environmental and Resources is the most appropriate primary category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Living Shorelines Enhancement for Coastal Resilience': Prediction(
#        reasoning='The policy centers on protecting and restoring coastal ecosystems (living shorelines and wetlands) to improve resilience and water resource management. It emphasizes natural infrastructure and habitat restoration rather than housing, governance, or economic policy.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Florida-Friendly Landscaping and Canal-Side Landscape Recertification': Prediction(
#        reasoning='The policy promotes water-saving landscaping practices and reduces nutrient runoff, tying directly to water resource management and pollution prevention. The emphasis on landscaping standards and canal-side recertification reflects environmental protection and land-use practices rather than housing, economy, or governance alone.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Ecosystem Monitoring and Green Infrastructure Net-Gain Development Policy': Prediction(
#        reasoning='The policy centers on monitoring ecosystem changes, assessing habitat protection, and quantifying carbon sequestration, plus a mitigation policy to ensure net gains in green infrastructure from development. The primary focus is managing natural resources and ecological integrity in the face of development rather than housing, governance alone, or social programs.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Protection and Expansion of Environmentally Endangered Lands (EEL)': Prediction(
#        reasoning='The policy aims to protect and manage lands identified as environmentally endangered or natural forest, and to expand the Environmentally Endangered Lands Program. The primary action is land protection, transfer to a conservation program, and ongoing land management focused on natural resources and habitat conservation. Therefore, it aligns with the Environmental and Resources category.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Water Conservation Targets and Landscape Irrigation Rebate Program': Prediction(
#        reasoning='The policy focuses on reducing water consumption and promoting efficient irrigation through rebates and assessments, targeting landscape water use. Its primary aim is water resource management and environmental sustainability, rather than housing construction or economic development. This aligns with managing natural resources and protecting water resources.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Open Space Master Plan Implementation for Flood and Heat Mitigation': Prediction(
#        reasoning='The policy centers on transforming open spaces to absorb water and mitigate flood risk and heat, using natural landscapes as climate-resilient infrastructure. This clearly falls under Environmental and Resources since it targets water resource management, land use, and ecosystem-based resilience rather than buildings or social program delivery.',
#        primary_category='Environmental and Resources',
#        confidence='high'
#    )},
#   {'Heat Mitigation and Health Task Force Actions': Prediction(
#        reasoning='The document centers on a coordinated policy and governance framework (Heat and Health Task Force) to plan and implement heat mitigation actions, which signals a governance and policy focus. The emphasis on strategies, coordination, and policy actions aligns with governance, rather than directly building infrastructure or managing resources.',
#        primary_category='Governance and Policy',
#        confidence='high'
#    )}]}

# %%
#for each city write down the policy name and policy details, match with built_policies dict per city per policy
master_dict = {}
for city in classified_policies.keys():
    master_dict[city] = []
    for policy_dict in classified_policies[city]:
        for policy_name, classification in policy_dict.items():
            # Find index of policy_name in built_policies to get details
            try:
                index = built_policies[city].policy_names.index(policy_name)
                policy_details = built_policies[city].policy_details[index]
            except ValueError:
                policy_details = "Details not found"
            master_dict[city].append({
                "Policy Name": policy_name,
                "Policy Details": policy_details,
                "Classification": classification.primary_category,
                "Confidence": classification.confidence,
                "Reasoning": classification.reasoning
            })

# %%
#want to write this to csv 
import csv
with open('classified_policies.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    # Write header
    writer.writerow(["City", "Policy Name", "Policy Details", "Classification", "Confidence", "Reasoning"])
    
    for city, policies in master_dict.items():
        for policy in policies:
            writer.writerow([
                city,
                policy["Policy Name"],
                policy["Policy Details"],
                policy["Classification"],
                policy["Confidence"],
                policy["Reasoning"]
            ])
